# %%
import hist 
import importdf as im
import importdf2 as im2
import importdf3 as im3

'''
설명
hist -> 히스토그램 그리는 함수 모아둔건데 visit_click(df)하나밖에 없음 아직 - 프리랜딩페이지 방문이랑 이메일 입력 히스토그램이랑 kde플랏 그려줌
importdf -> 전세계 다 모아둔거
importdf2 -> 미국 모아둔거
importdf3 -> 인도네시아 모아둔거

변수명 규칙
df숫자 - 11월 (숫자)일 전세계 DF
us숫자 - 11월 (숫자)일 미국 DF
indo숫자 - 11월 (숫자)일 인도네시아 DF
(위치)_all - 전체 기간(10일~15일) DF

예시 - df11 us12 indo14 indo_all
'''
print('')

# %%
#미국 데이터
hist.visit_click(im2.us10)
hist.visit_click(im2.us11)
hist.visit_click(im2.us12)
hist.visit_click(im2.us13)
hist.visit_click(im2.us14)
hist.visit_click(im2.us15)

hist.visit_click(im2.us_all)

# %%
#인도네시아 데이터
hist.visit_click(im3.indo10)
hist.visit_click(im3.indo11)
hist.visit_click(im3.indo12)
hist.visit_click(im3.indo13)
hist.visit_click(im3.indo14)
hist.visit_click(im3.indo15)

hist.visit_click(im3.indo_all)

# %%
#전세계 데이터

hist.visit_click(im.df10)
hist.visit_click(im.df11)
hist.visit_click(im.df12)
hist.visit_click(im.df13)
hist.visit_click(im.df14)
hist.visit_click(im.df15)

hist.visit_click(im.df_all)
