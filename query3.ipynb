# %%
import hist 
import importdf as im

# %%
im.df10
# Out:
#       event_date     event_name   event_timestamp  user_pseudo_id  \
# 0       20201110    first_visit  1605002482512825    1.610704e+09
# 1       20201110  session_start  1605002482512825    1.610704e+09
# 2       20201110      page_view  1605002482512825    1.610704e+09
# 3       20201110      page_view  1605002489732341    1.610704e+09
# 4       20201110         scr_10  1605002497793032    1.610704e+09
# ...          ...            ...               ...             ...
# 8004    20201110      page_view  1605031558869112    1.692238e+08
# 8005    20201110         scr_10  1605031565701118    1.692238e+08
# 8006    20201110         scr_50  1605031600225041    1.692238e+08
# 8007    20201110         scr_90  1605031638446723    1.692238e+08
# 8008    20201110         scroll  1605031643452763    1.692238e+08
#
#       ltv_revenue device_language device_is_limited_ad_tracking  \
# 0             0.0           zh-cn                            No
# ...

# %%
hist.visit_click(im.df10)

# %%
hist.visit_click(im.us10)

# %%
hist.visit_click(im.df11)

# %%
hist.visit_click(im.us11)

# %%
hist.visit_click(im.df12)

# %%
hist.visit_click(im.us12)

# %%
hist.visit_click(im.df13)

# %%
hist.visit_click(im.us13)

# %%
hist.visit_click(im.df_all)
